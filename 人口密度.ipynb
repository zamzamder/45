# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('https://data.moi.gov.tw/MoiOD/System/DownloadFile.aspx?DATA=47072428-5C8F-4897-8535-DBF583572597')
display(df.head())
新北= df.loc[1:29,['site_id','people_total','area']]
display(新北.head(29))
台北= df.loc[30:41,['site_id','people_total','area']]
display(台北.head(12))
桃園= df.loc[42:53,['site_id','people_total','area']]
display(桃園.head(12))
台中= df.loc[55:83,['site_id','people_total','area']]
display(台中.head(12))
台南= df.loc[84:120,['site_id','people_total','area']]
display(台南.head(12))
高雄= df.loc[121:158,['site_id','people_total','area']]
display(高雄.head(12))
宜蘭= df.loc[159:170,['site_id','people_total','area']]
display(宜蘭.head(12))
新竹= df.loc[171:183,['site_id','people_total','area']]
display(新竹.head(12))
苗栗= df.loc[184:201,['site_id','people_total','area']]
display(苗栗.head(12))
彰化= df.loc[202:227,['site_id','people_total','area']]
display(彰化.head(12))
南投= df.loc[228:240,['site_id','people_total','area']]
display(南投.head(12))
雲林= df.loc[241:260,['site_id','people_total','area']]
display(雲林.head(12))
嘉義= df.loc[261:278,['site_id','people_total','area']]
display(嘉義.head(12))
屏東= df.loc[279:311,['site_id','people_total','area']]
display(屏東.head(12))
台東= df.loc[312:327,['site_id','people_total','area']]
display(台東.head(12))
花蓮= df.loc[328:340,['site_id','people_total','area']]
display(花蓮.head(12))
澎湖= df.loc[341:346,['site_id','people_total','area']]
display(澎湖.head(12))
基隆市= df.loc[347:353,['site_id','people_total','area']]
display(基隆市.head(12))
新竹市= df.loc[354:356,['site_id','people_total','area']]
display(新竹市.head(12))
嘉義市= df.loc[357:358,['site_id','people_total','area']]
display(嘉義市.head(12))
金門= df.loc[359:364,['site_id','people_total','area']]
display(金門.head(12))
連江縣= df.loc[365:368,['site_id','people_total','area']]
display(連江縣.head(12))
df1= pd.read_excel(r"D:123.xlsx")


display(df1.head(22))
print(df1['名稱'][0],df1['人口密度'][0])
print(df1['人口密度'])
df2=[df1['名稱'][0],df1['名稱'][4],df1['名稱'][6],df1['名稱'][10],df1['名稱'][8]]
df3=[df1['人口密度'][0],df1['人口密度'][4],df1['人口密度'][6],df1['人口密度'][10],df1['人口密度'][8]]
# Out:
#   statistic_yyy site_id people_total     area population_density
# 0           統計年     區域別        年底人口數     土地面積               人口密度
# 1           108  新北市板橋區       556897  23.1373              24069
# 2           108  新北市三重區       386336   16.317              23677
# 3           108  新北市中和區       413069   20.144              20506
# 4           108  新北市永和區       220595   5.7138              38607
#    site_id people_total      area
# 1   新北市板橋區       556897   23.1373
# 2   新北市三重區       386336    16.317
# 3   新北市中和區       413069    20.144
# 4   新北市永和區       220595    5.7138
# 5   新北市新莊區       420473   19.7383
# 6   新北市新店區       303445  120.2255
# 7   新北市樹林區       183926   33.1288
# 8   新北市鶯歌區        86869   21.1248
# 9   新北市三峽區       116478  191.4508
# 10  新北市淡水區       178610   70.6565
# 11  新北市汐止區       203429   71.2354
# 12  新北市瑞芳區        39536   70.7336
# 13  新北市土城區       237696   29.5578
# 14  新北市蘆洲區       201883    7.4351
# 15  新北市五股區        88000   34.8632
# ...

# %%
import requests, json
import urllib3
from datetime import datetime

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)



start = datetime.now()
url = "https://od.cdc.gov.tw/eic/Dengue_Daily_last12m_EN.json"
res = requests.get(url)


sites = res.json()
count = int(0)
dd = {'Taipei City':0,'New Taipei City':0,'Taichung City':0,'Tainan City':0,'Kaohsiung City':0}

for site in sites:
    if site['County_living']=='Taipei City':
        dd['Taipei City'] += 1
    elif site['County_living']=='New Taipei City':
        dd['New Taipei City'] += 1 
    elif site['County_living']=='Taichung City':
        dd['Taichung City'] += 1 
    elif site['County_living']=='Tainan City':
        dd['Tainan City'] += 1 
    elif site['County_living']=='Kaohsiung City':
        dd['Kaohsiung City'] += 1 
        
print(dd)
# Out:
# {'Taipei City': 80, 'New Taipei City': 92, 'Taichung City': 56, 'Tainan City': 51, 'Kaohsiung City': 111}

# %%
df4=[dd['Taipei City'],dd['New Taipei City'],dd['Taichung City'],dd['Tainan City'],dd['Kaohsiung City']]
print(df4)
# Out:
# [80, 92, 56, 51, 111]

# %%
x = df2
y = df3
z = df4

fig, ax1 = plt.subplots()


ax1.set_xlabel('城市')
ax1.set_ylabel('人口密度', color='r')
ax1.bar(x, y,align = "edge", width = -0.35, color='r')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  


ax2.set_ylabel('登革熱人數', color='b')  
ax2.bar(x, z,align = "edge", width = 0.35, color='b')
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  
plt.show()
